# %% [markdown]
# Exercici 1
# Mostra els 2 primers comentaris que hi ha en la base de dades.
# Quants usuaris tenim registrats?
# Quants cinemes hi ha en l'estat de Califòrnia?
# Quin va ser el primer usuari/ària en registrar-se?
# Quantes pel·lícules de comèdia hi ha en la nostra base de dades

# %% [markdown]
# #Excercici 1, 2 comments
#
# ![image.png](attachment:image.png)
#
# El limite de 2 registros nos permite ver solo los dos primeros. Los comentarios los podemos encontrar en la entrada 'text' ded cada registro.

# %% [markdown]
# #Excercici 1, usuariors registrados
#
# ![image.png](attachment:image.png)
#
# arriba a la derecha podemos ver como hay 185 usuarios registrados

# %% [markdown]
# #Excercici 1, cines en california
#
#
# ![image.png](attachment:image.png)
#
# Hay 169 cines en california (CA)

# %% [markdown]
# #Excercici 1, primer usuario registrado
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #Excercici 1, cuantas pelis de comedia
#
# ![image.png](attachment:image.png)
#
# Hay 7024 peliculas de comedia en nuestra base de datos

# %% [markdown]
# #Exercici 2: Mostra'm tots els documents de les pel·lícules produïdes en 1932, però que el gènere sigui drama o estiguin en francès.
#
#
# ![image.png](attachment:image.png)
#
# Hay cuatro peliculas que cumplen estas condiciones

# %% [markdown]
# #Exercici 3 Mostra'm tots els documents de pel·lícules estatunidenques que tinguin entre 5 i 9 premis que van ser produïdes entre 2012 i 2014.
#
# ![image.png](attachment:image.png)
#
# 166 peliculas cumplen estas condiciones
